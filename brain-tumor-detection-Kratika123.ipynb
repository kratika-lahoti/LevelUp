# %% [markdown]
# **<center><font size=5>Brain Tumor Detection with VGG-16 Model</font></center>**
# ***
# **author**: Ruslan Klymentiev
#
# **date**: 10th June, 2019
#
# **Table of Contents**
# - <a href='#intro'>1. Project Overview and Objectives</a>
#     - <a href='#dataset'>1.1. Data Set Description</a>
#     - <a href='#tumor'>1.2. What is Brain Tumor?</a>
# - <a href='#env'>2. Setting up the Environment</a>
# - <a href='#import'>3. Data Import and Preprocessing</a>
# - <a href='#cnn'>4. CNN Model</a>
#     - <a href='#aug'>4.1. Data Augmentation</a>
#         - <a href='#demo'>4.1.1. Demo</a>
#         - <a href='#apply'>4.1.2. Apply</a>
#     - <a href='#build'>4.2. Model Building</a>
#     - <a href='#perf'>4.3. Model Performance</a>
# - <a href='#concl'>5. Conclusions</a>

# %% [markdown]
# # <a id='intro'>1. Project Overview and Objectives</a>
#
# The main purpose of this project was to build a CNN model that would classify if subject has a tumor or not base on MRI scan. I used the [VGG-16](https://www.kaggle.com/navoneel/brain-mri-images-for-brain-tumor-detection) model architecture and weights to train the model for this binary problem. I used `accuracy` as a metric to justify the model performance which can be defined as:
#
# $\textrm{Accuracy} = \frac{\textrm{Number of correclty predicted images}}{\textrm{Total number of tested images}} \times 100\%$
#
# Final results look as follows:
#
# | Set | Accuracy |
# |:-:|:-:|
# | Validation Set* | ~88% |
# | Test Set* | ~80% |
# <br>
# \* *Note: there might be some misunderstanding in terms of set names so I want to describe what do I mean by `test` and `validation` set:*
# * *`validation set` - is the set used during the model training to adjust the hyperparameters. *
# * *`test set` - is the small set that I don't touch for the whole training process at all. It's been used for final model performance evaluation.*
#
# ## <a id='dataset'>1.1. Data Set Description</a>
#
# The image data that was used for this problem is [Brain MRI Images for Brain Tumor Detection](https://www.kaggle.com/navoneel/brain-mri-images-for-brain-tumor-detection). It conists of MRI scans of two classes:
#
# * `NO` - no tumor, encoded as `0`
# * `YES` - tumor, encoded as `1`
#
# Unfortunately, the data set description doesn't hold any information where this MRI scans come from and so on.
#
# ## <a id='tumor'>1.2. What is Brain Tumor?</a>
#
# > A brain tumor occurs when abnormal cells form within the brain. There are two main types of tumors: cancerous (malignant) tumors and benign tumors. Cancerous tumors can be divided into primary tumors, which start within the brain, and secondary tumors, which have spread from elsewhere, known as brain metastasis tumors. All types of brain tumors may produce symptoms that vary depending on the part of the brain involved. These symptoms may include headaches, seizures, problems with vision, vomiting and mental changes. The headache is classically worse in the morning and goes away with vomiting. Other symptoms may include difficulty walking, speaking or with sensations. As the disease progresses, unconsciousness may occur.
# >
# > ![](https://upload.wikimedia.org/wikipedia/commons/5/5f/Hirnmetastase_MRT-T1_KM.jpg)
# >
# > *Brain metastasis in the right cerebral hemisphere from lung cancer, shown on magnetic resonance imaging.*
#
# Source: [Wikipedia](https://en.wikipedia.org/wiki/Brain_tumor)

# %% [markdown]
# # <a id='env'>2. Setting up the Environment</a>

# %%
import numpy as np 
from tqdm import tqdm
import cv2
import os
import shutil
import itertools
import imutils
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools

from keras.preprocessing.image import ImageDataGenerator
from keras.applications.vgg16 import VGG16, preprocess_input
from keras import layers
from keras.models import Model, Sequential
from keras.optimizers import Adam, RMSprop
from keras.callbacks import EarlyStopping

init_notebook_mode(connected=True)
RANDOM_SEED = 123
# Out:
# Using TensorFlow backend.
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# Right now all images are in one folder with `yes` and `no` subfolders. I will split the data into `train`, `val` and `test` folders which makes its easier to work for me. The new folder heirarchy will look as follows:

# %%
IMG_PATH ='brain_tumor_dataset'
# split the data by train/val/test
for CLASS in os.listdir(IMG_PATH):
    if not CLASS. ('.'):
        IMG_NUM = len(os.listdir(IMG_PATH +"/" + CLASS))
        for (n, FILE_NAME) in enumerate(os.listdir(IMG_PATH+"/" + CLASS)):
            img = IMG_PATH +"/" + CLASS + '/' + FILE_NAME
            if n < 5:
                shutil.copy(img, 'TEST/' + CLASS.upper() + '/' + FILE_NAME)
            elif n < 0.8*IMG_NUM:
                shutil.copy(img, 'TRAIN/'+ CLASS.upper() + '/' + FILE_NAME)
            else:
                shutil.copy(img, 'VAL/'+ CLASS.upper() + '/' + FILE_NAME)

# %% [markdown]
# # <a id='import'>3. Data Import and Preprocessing</a>

# %%
def load_data(dir_path, img_size=(100,100)):
    """
    Load resized images as np.arrays to workspace
    """
    X = []
    y = []
    i = 0
    labels = dict()
    for path in tqdm(sorted(os.listdir(dir_path))):
        if not path.startswith('.'):
            labels[i] = path
            for file in os.listdir(dir_path + path):
                if not file.startswith('.'):
                    img = cv2.imread(dir_path + path + '/' + file)
                    X.append(img)
                    y.append(i)
            i += 1
    X = np.array(X)
    y = np.array(y)
    print(f'{len(X)} images loaded from {dir_path} directory.')
    return X, y, labels



def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize = (6,6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    cm = np.round(cm,2)
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
TRAIN_DIR = 'TRAIN/'
TEST_DIR = 'TEST/'
VAL_DIR = 'VAL/'
IMG_SIZE = (224,224)

# use predefined function to load the image data into workspace
X_train, y_train, labels = load_data(TRAIN_DIR, IMG_SIZE)
X_test, y_test, _ = load_data(TEST_DIR, IMG_SIZE)
X_val, y_val, _ = load_data(VAL_DIR, IMG_SIZE)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:01<00:00,  2.27it/s]
# 193 images loaded from TRAIN/ directory.
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 109.09it/s]
# 10 images loaded from TEST/ directory.
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  9.25it/s]
# 50 images loaded from VAL/ directory.

# %% [markdown]
# Let's take a look at the distribution of classes among sets:

# %%
y = dict()
y[0] = []
y[1] = []
for set_name in (y_train, y_val, y_test):
    y[0].append(np.sum(set_name == 0))
    y[1].append(np.sum(set_name == 1))

trace0 = go.Bar(
    x=['Train Set', 'Validation Set', 'Test Set'],
    y=y[0],
    name='No',
    marker=dict(color='#33cc33'),
    opacity=0.7
)
trace1 = go.Bar(
    x=['Train Set', 'Validation Set', 'Test Set'],
    y=y[1],
    name='Yes',
    marker=dict(color='#ff3300'),
    opacity=0.7
)
data = [trace0, trace1]
layout = go.Layout(
    title='Count of classes in each set',
    xaxis={'title': 'Set'},
    yaxis={'title': 'Count'}
)
fig = go.Figure(data, layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="0c81ce8a-5f79-42d4-a792-1cf88406b277" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0c81ce8a-5f79-42d4-a792-1cf88406b277")) {
#                     Plotly.newPlot(
#                         '0c81ce8a-5f79-42d4-a792-1cf88406b277',
#                         [{"marker": {"color": "#33cc33"}, "name": "No", "opacity": 0.7, "type": "bar", "x": ["Train Set", "Validation Set", "Test Set"], "y": [74, 19, 5]}, {"marker": {"color": "#ff3300"}, "name": "Yes", "opacity": 0.7, "type": "bar", "x": ["Train Set", "Validation Set", "Test Set"], "y": [119, 31, 5]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scat ...

# %%
def plot_samples(X, y, labels_dict, n=50):
    """
    Creates a gridplot for desired number of images (n) from the specified set
    """
    for index in range(len(labels_dict)):
        imgs = X[np.argwhere(y == index)][:n]
        j = 10
        i = int(n/j)

        plt.figure(figsize=(15,6))
        c = 1
        for img in imgs:
            plt.subplot(i,j,c)
            plt.imshow(img[0])

            plt.xticks([])
            plt.yticks([])
            c += 1
        plt.suptitle('Tumor: {}'.format(labels_dict[index]))
        plt.show()

# %%
plot_samples(X_train, y_train, labels, 30)

# %% [markdown]
# As you can see, images have different `width` and `height` and diffent size of "black corners". Since the image size for VGG-16 imput layer is `(224,224)` some wide images may look weird after resizing. Histogram of ratio distributions (`ratio = width/height`):

# %%
RATIO_LIST = []
for set in (X_train, X_test, X_val):
    for img in set:
        RATIO_LIST.append(img.shape[1]/img.shape[0])
        
plt.hist(RATIO_LIST)
plt.title('Distribution of Image Ratios')
plt.xlabel('Ratio Value')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# The first step of "normalization" would be to crop the brain out of the images. I used technique which was perfectly described in [pyimagesearch](https://www.pyimagesearch.com/2016/04/11/finding-extreme-points-in-contours-with-opencv/) blog and I highly suggest to looks deeper into it.

# %%
def crop_imgs(set_name, add_pixels_value=0):
    """
    Finds the extreme points on the image and crops the rectangular out of them
    """
    set_new = []
    for img in set_name:
        gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        gray = cv2.GaussianBlur(gray, (5, 5), 0)

        # threshold the image, then perform a series of erosions +
        # dilations to remove any small regions of noise
        thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
        thresh = cv2.erode(thresh, None, iterations=2)
        thresh = cv2.dilate(thresh, None, iterations=2)

        # find contours in thresholded image, then grab the largest one
        cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        cnts = imutils.grab_contours(cnts)
        c = max(cnts, key=cv2.contourArea)

        # find the extreme points
        extLeft = tuple(c[c[:, :, 0].argmin()][0])
        extRight = tuple(c[c[:, :, 0].argmax()][0])
        extTop = tuple(c[c[:, :, 1].argmin()][0])
        extBot = tuple(c[c[:, :, 1].argmax()][0])

        ADD_PIXELS = add_pixels_value
        new_img = img[extTop[1]-ADD_PIXELS:extBot[1]+ADD_PIXELS, extLeft[0]-ADD_PIXELS:extRight[0]+ADD_PIXELS].copy()
        set_new.append(new_img)

    return np.array(set_new)

# %% [markdown]
# Let's look at example what this function will do with MRI scans:

# %%
img = cv2.imread('brain_tumor_dataset/yes/Y108.jpg')
img = cv2.resize(
            img,
            dsize=IMG_SIZE,
            interpolation=cv2.INTER_CUBIC
        )
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
gray = cv2.GaussianBlur(gray, (5, 5), 0)

# threshold the image, then perform a series of erosions +
# dilations to remove any small regions of noise
thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
thresh = cv2.erode(thresh, None, iterations=2)
thresh = cv2.dilate(thresh, None, iterations=2)

# find contours in thresholded image, then grab the largest one
cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = imutils.grab_contours(cnts)
c = max(cnts, key=cv2.contourArea)

# find the extreme points
extLeft = tuple(c[c[:, :, 0].argmin()][0])
extRight = tuple(c[c[:, :, 0].argmax()][0])
extTop = tuple(c[c[:, :, 1].argmin()][0])
extBot = tuple(c[c[:, :, 1].argmax()][0])

# add contour on the image
img_cnt = cv2.drawContours(img.copy(), [c], -1, (0, 255, 255), 4)

# add extreme points
img_pnt = cv2.circle(img_cnt.copy(), extLeft, 8, (0, 0, 255), -1)
img_pnt = cv2.circle(img_pnt, extRight, 8, (0, 255, 0), -1)
img_pnt = cv2.circle(img_pnt, extTop, 8, (255, 0, 0), -1)
img_pnt = cv2.circle(img_pnt, extBot, 8, (255, 255, 0), -1)

# crop
ADD_PIXELS = 0
new_img = img[extTop[1]-ADD_PIXELS:extBot[1]+ADD_PIXELS, extLeft[0]-ADD_PIXELS:extRight[0]+ADD_PIXELS].copy()

# %%
plt.figure(figsize=(15,6))
plt.subplot(141)
plt.imshow(img)
plt.xticks([])
plt.yticks([])
plt.title('Step 1. Get the original image')
plt.subplot(142)
plt.imshow(img_cnt)
plt.xticks([])
plt.yticks([])
plt.title('Step 2. Find the biggest contour')
plt.subplot(143)
plt.imshow(img_pnt)
plt.xticks([])
plt.yticks([])
plt.title('Step 3. Find the extreme points')
plt.subplot(144)
plt.imshow(new_img)
plt.xticks([])
plt.yticks([])
plt.title('Step 4. Crop the image')
plt.show()

# %%
# apply this for each set
X_train_crop = crop_imgs(set_name=X_train)
X_val_crop = crop_imgs(set_name=X_val)
X_test_crop = crop_imgs(set_name=X_test)

# %%
plot_samples(X_train_crop, y_train, labels, 30)

# %%
def save_new_images(x_set, y_set, folder_name):
    i = 0
    for (img, imclass) in zip(x_set, y_set):
        if imclass == 0:
            cv2.imwrite(folder_name+'NO/'+str(i)+'.jpg', img)
        else:
            cv2.imwrite(folder_name+'YES/'+str(i)+'.jpg', img)
        i += 1

# %%
# saving new images to the folder
#!mkdir TRAIN_CROP TEST_CROP VAL_CROP TRAIN_CROP/YES TRAIN_CROP/NO TEST_CROP/YES TEST_CROP/NO VAL_CROP/YES VAL_CROP/NO
#
save_new_images(X_train_crop, y_train, folder_name='TRAIN_CROP/')
save_new_images(X_val_crop, y_val, folder_name='VAL_CROP/')
save_new_images(X_test_crop, y_test, folder_name='TEST_CROP/')

# %% [markdown]
# The next step would be resizing images to `(224,224)` and applying preprocessing needed for VGG-16 model input.

# %%
def preprocess_imgs(set_name, img_size):
    """
    Resize and apply VGG-15 preprocessing
    """
    set_new = []
    for img in set_name:
        img = cv2.resize(
            img,
            dsize=img_size,
            interpolation=cv2.INTER_CUBIC
        )
        set_new.append(preprocess_input(img))
    return np.array(set_new)

# %%
X_train_prep = preprocess_imgs(set_name=X_train_crop, img_size=IMG_SIZE)
X_test_prep = preprocess_imgs(set_name=X_test_crop, img_size=IMG_SIZE)
X_val_prep = preprocess_imgs(set_name=X_val_crop, img_size=IMG_SIZE)

# %%
# plot_samples(X_train_prep, y_train, labels, 30)

# %% [markdown]
# # <a id='cnn'>4. CNN Model</a>
#
# I was using [Transfer Learning](https://towardsdatascience.com/keras-transfer-learning-for-beginners-6c9b8b7143e) with VGG-16 architecture and weights as a base model.
#
# ## <a id='aug'>4.1. Data Augmentation</a>
#
# Since I had small data set I used the technique called [Data Augmentation](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html) which helps to "increase" the size of training set.
#
# ### <a id='demo'>4.1.1. Demo</a>
#
# That's the example from one image how does augmentation look like.

# %%
# set the paramters we want to change randomly
demo_datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.05,
    height_shift_range=0.05,
    rescale=1./255,
    shear_range=0.05,
    brightness_range=[0.1, 1.5],
    horizontal_flip=True,
    vertical_flip=True
)

# %%
#os.mkdir('preview')
x = X_train_crop[0]  
x = x.reshape((1,) + x.shape) 

i = 0
for batch in demo_datagen.flow(x, batch_size=1, save_to_dir='preview', save_prefix='aug_img', save_format='jpg'):
    i += 1
    if i > 20:
        break

# %%
plt.imshow(X_train_crop[0])
plt.xticks([])
plt.yticks([])
plt.title('Original Image')
plt.show()

plt.figure(figsize=(15,6))
i = 1
for img in os.listdir('preview/'):
    img = cv2.cv2.imread('preview/' + img)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.subplot(3,7,i)
    plt.imshow(img)
    plt.xticks([])
    plt.yticks([])
    i += 1
    if i > 3*7:
        break
plt.suptitle('Augemented Images')
plt.show()

# %%
import os 
TRAIN_DIR = 'TRAIN_CROP/'
VAL_DIR = 'VAL_CROP/'

if not os.path.exists(TRAIN_DIR):
    os.makedirs(TRAIN_DIR)
if not os.path.exists(VAL_DIR):
    os.makedirs(VAL_DIR)

# %% [markdown]
# ### <a id='apply'>4.1.2. Apply</a>

# %%
TRAIN_DIR = 'TRAIN_CROP/'
VAL_DIR = 'VAL_CROP/'

train_datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    brightness_range=[0.5, 1.5],
    horizontal_flip=True,
    vertical_flip=True,
    preprocessing_function=preprocess_input
)

test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)


train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    color_mode='rgb',
    target_size=IMG_SIZE,
    batch_size=32,
    class_mode='binary',
    seed=RANDOM_SEED
)


validation_generator = test_datagen.flow_from_directory(
    VAL_DIR,
    color_mode='rgb',
    target_size=IMG_SIZE,
    batch_size=16,
    class_mode='binary',
    seed=RANDOM_SEED
)
# Out:
# Found 193 images belonging to 2 classes.
# Found 50 images belonging to 2 classes.

# %% [markdown]
# ## <a id='build'>4.2. Model Building</a>

# %%
# load base model
vgg16_weight_path = 'vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5'
base_model = VGG16(
    weights=vgg16_weight_path,
    include_top=False, 
    input_shape=IMG_SIZE + (3,)
)

# %%
NUM_CLASSES = 1

model = Sequential()
model.add(base_model)
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(NUM_CLASSES, activation='sigmoid'))

model.layers[0].trainable = False

model.compile(
    loss='binary_crossentropy',
    optimizer=RMSprop(lr=1e-4),
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 25088)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 25089
# =================================================================
# Total params: 14,739,777
# Trainable params: 25,089
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
EPOCHS = 10
es = EarlyStopping(
    monitor='val_accuracy', 
    mode='max',
    patience=6
)
    
history = model.fit_generator(
    train_generator,
    steps_per_epoch=50,
    epochs=EPOCHS,
    validation_data=validation_generator,
    validation_steps=25,
    callbacks=[es]
)
# Out:
# Epoch 1/10
# 50/50 [==============================] - ETA: 1:51 - loss: 3.4631 - accuracy: 0.0000e+ - ETA: 10:57 - loss: 6.1248 - accuracy: 0.4848   - ETA: 14:28 - loss: 7.2958 - accuracy: 0.415 - ETA: 16:07 - loss: 6.9994 - accuracy: 0.484 - ETA: 16:37 - loss: 7.2701 - accuracy: 0.480 - ETA: 16:45 - loss: 7.2546 - accuracy: 0.484 - ETA: 16:57 - loss: 6.9417 - accuracy: 0.497 - ETA: 16:48 - loss: 6.6553 - accuracy: 0.506 - ETA: 16:37 - loss: 6.6873 - accuracy: 0.509 - ETA: 14:39 - loss: 6.0185 - accuracy: 0.511 - ETA: 14:34 - loss: 6.1470 - accuracy: 0.517 - ETA: 14:24 - loss: 6.1556 - accuracy: 0.515 - ETA: 14:13 - loss: 5.9423 - accuracy: 0.528 - ETA: 14:04 - loss: 5.9282 - accuracy: 0.520 - ETA: 13:48 - loss: 5.9606 - accuracy: 0.516 - ETA: 13:30 - loss: 5.8638 - accuracy: 0.522 - ETA: 12:22 - loss: 6.1086 - accuracy: 0.521 - ETA: 12:07 - loss: 5.8909 - accuracy: 0.532 - ETA: 11:50 - loss: 5.8077 - accuracy: 0.534 - ETA: 11:33 - loss: 5.7077 - accuracy: 0.541 - ETA: 11:18 - loss: 5.8353 - accuracy: 0.537 - ETA: 10:58 - loss: 5.7481 - accuracy: 0.538 - ETA: 10:38 - loss: 5.7209 - accuracy: 0.536 - ETA: 10:18 - loss: 5.5955 - accuracy: 0.545 - ETA: 9:57 - loss: 5.6763 - accuracy: 0.550 - ETA: 9:12 - loss: 5.4581 - accuracy: 0.55 - ETA: 8:52 - loss: 5.4195 - accuracy: 0.55 - ETA: 8:33 - loss: 5.3968 - accuracy: 0.55 - ETA: 8:12 - loss: 5.3758 - accuracy: 0.55 - ETA: 7:52 - loss: 5.3667 - accuracy: 0.56 - ETA: 7:30 - loss: 5.3864 - accuracy: 0.56 - ETA: 7:08 - loss: 5.4358 - accuracy: 0.56 - ETA: 6:45 - loss: 5.3573 - accuracy: 0.56 - ETA: 6:23 - loss: 5.3626 - accuracy: 0.56 - ETA: 5:49 - loss: 5.2094 - accuracy: 0.56 - ETA: 5:28 - loss: 5.1490 - accuracy: 0.57 - ETA: 5:05 - loss: 5.1039 - accuracy: 0.57 - ETA: 4:43 - loss: 5.0135 - accuracy: 0.57 - ETA: 4:20 - loss: 4.9518 - accuracy: 0.57 - ETA: 3:51 - loss: 4.8280 - accuracy: 0.57 - ETA: 3:28 - loss: 4.8076 - accuracy: 0.57 - ETA: 3:06 - loss: 4.7843 - accuracy: 0.57 - ETA: 2:43 - loss: 4.8032 - accuracy: 0.57 - ETA: 2:17 - loss: 4.7061 - accuracy: 0.57 - ETA: 1:54 - loss: 4.6951 - accuracy: 0.57 - ETA: 1:32 - loss: 4.6770 - accuracy: 0.57 - ETA: 1:09 - loss: 4.6140 - accuracy: 0.58 - ETA: 46s - loss: 4.5773 - accuracy: 0.5853 - ETA: 23s - loss: 4.5139 - accuracy: 0.589 - 1431s 29s/step - loss: 4.5303 - accuracy: 0.5879 - val_loss: 1.4577 - val_accuracy: 0.8228
# Epoch 2/10
# 50/50 [==============================] - ETA: 21:36 - loss: 2.2015 - accuracy: 0.718 - ETA: 21:09 - loss: 3.8699 - accuracy: 0.625 - ETA: 20:42 - loss: 3.4462 - accuracy: 0.635 - ETA: 15:22 - loss: 2.5847 - accuracy: 0.639 - ETA: 16:02 - loss: 2.6119 - accuracy: 0.627 - ETA: 16:31 - loss: 2.5966 - accuracy: 0.646 - ETA: 16:32 - loss: 2.8067 - accuracy: 0.652 - ETA: 14:13 - loss: 2.4559 - accuracy: 0.654 - ETA: 14:20 - loss: 2.4405 - accuracy: 0.663 - ETA: 14:22 - loss: 2.5833 - accuracy: 0.655 - ETA: 14:18 - loss: 2.6181 - accuracy: 0.669 - ETA: 14:10 - loss: 2.7712 - accuracy: 0.664 - ETA: 14:04 - loss: 2.9282 - accuracy: 0.666 - ETA: 13:51 - loss: 2.9075 - accuracy: 0.673 - ETA: 13:36 - loss: 2.7851 - accuracy: 0.686 - ETA: 13:20 - loss: 2.7636 - accuracy: 0.691 - ETA: 13:02 - loss: 2.7998 - accuracy: 0.686 - ETA: 11:58 - loss: 2.6443 - accuracy: 0.687 - ETA: 11:42 - loss: 2.6123 - accuracy: 0.687 - ETA: 11:28 - loss: 2.5910 - accuracy: 0.698 - ETA: 11:10 - loss: 2.5793 - accuracy: 0.706 - ETA: 10:19 - loss: 2.4620 - accuracy: 0.706 - ETA: 10:02 - loss: 2.4724 - accuracy: 0.709 - ETA: 9:44 - loss: 2.5285 - accuracy: 0.709 - ETA: 9:26 - loss: 2.6208 - accuracy: 0.70 - ETA: 9:07 - loss: 2.5916 - accuracy: 0.70 - ETA: 8:49 - loss: 2.6110 - accuracy: 0.70 - ETA: 8:08 - loss: 2.5178 - accuracy: 0.70 - ETA: 7:49 - loss: 2.5461 - accuracy: 0.70 - ETA: 7:30 - loss: 2.4947 - accuracy: 0.70 - ETA: 7:10 - loss: 2.4643 - accuracy: 0.71 - ETA: 6:49 - loss: 2.4673 - accuracy: 0.70 - ETA: 6:28 - loss: 2.4885 - accuracy: 0.70 - ETA: 6:08 - loss: 2.5633 - accuracy: 0.70 - ETA: 5:46 - loss: 2.6154 - accuracy: 0.70 - ETA: 5:25 - loss: 2.6611 - accuracy: 0.70 - ETA: 5:03 - loss: 2.6840 - accuracy: 0.69 - ETA: 4:40 - loss: 2.6944 - accuracy: 0.70 - ETA: 4:18 - loss: 2.6889 - accuracy: 0.70 - ETA: 3:55 - loss: 2.7127 - accuracy: 0.70 - ETA: 3:27 - loss: 2.6465 - accuracy: 0.70 - ETA: 2:59 - loss: 2.5837 - accuracy: 0.70 - ETA: 2:38 - loss: 2.5787 - accuracy: 0.70 - ETA: 2:16 - loss: 2.6296 - accuracy: 0.70 - ETA: 1:53 - loss: 2.6022 - accuracy: 0.70 - ETA: 1:31 - loss: 2.6657 - accuracy: 0.70 - ETA: 1:08 - loss: 2.6397 - accuracy: 0.70 - ETA: 46s - loss: 2.6818 - accuracy: 0.7066 - ETA: 23s - loss: 2.6846 - accuracy: 0.706 - 1422s 28s/step - loss: 2.6634 - accuracy: 0.7093 - val_loss: 0.1434 - val_accuracy: 0.9177
# Epoch 3/10
# 50/50 [==============================] - ETA: 21:37 - loss: 5.9700 - accuracy: 0.562 - ETA: 21:10 - loss: 4.6098 - accuracy: 0.593 - ETA: 14:03 - loss: 3.0732 - accuracy: 0.600 - ETA: 15:23 - loss: 2.8487 - accuracy: 0.649 - ETA: 16:20 - loss: 3.0791 - accuracy: 0.666 - ETA: 16:32 - loss: 3.4762 - accuracy: 0.664 - ETA: 16:33 - loss: 3.4680 - accuracy: 0.663 - ETA: 16:28 - loss: 3.6514 - accuracy: 0.644 - ETA: 16:18 - loss: 3.3463 - accuracy: 0.661 - ETA: 14:22 - loss: 3.0117 - accuracy: 0.662 - ETA: 14:19 - loss: 3.0229 - accuracy: 0.665 - ETA: 14:17 - loss: 3.0550 - accuracy: 0.667 - ETA: 14:05 - loss: 3.0277 - accuracy: 0.669 - ETA: 12:46 - loss: 2.8114 - accuracy: 0.670 - ETA: 12:37 - loss: 2.8871 - accuracy: 0.661 - ETA: 12:26 - loss: 2.8527 - accuracy: 0.665 - ETA: 12:13 - loss: 2.7795 - accuracy: 0.678 - ETA: 11:59 - loss: 2.7512 - accuracy: 0.685 - ETA: 11:46 - loss: 2.8327 - accuracy: 0.683 - ETA: 11:28 - loss: 2.8209 - accuracy: 0.692 - ETA: 11:11 - loss: 2.8345 - accuracy: 0.694 - ETA: 10:52 - loss: 2.8275 - accuracy: 0.695 - ETA: 10:32 - loss: 2.7776 - accuracy: 0.703 - ETA: 10:12 - loss: 2.8276 - accuracy: 0.705 - ETA: 9:52 - loss: 2.8074 - accuracy: 0.704 - ETA: 9:07 - loss: 2.6994 - accuracy: 0.70 - ETA: 8:49 - loss: 2.6918 - accuracy: 0.70 - ETA: 8:29 - loss: 2.6626 - accuracy: 0.71 - ETA: 8:08 - loss: 2.6747 - accuracy: 0.71 - ETA: 7:47 - loss: 2.6713 - accuracy: 0.71 - ETA: 7:26 - loss: 2.6149 - accuracy: 0.72 - ETA: 6:49 - loss: 2.5331 - accuracy: 0.72 - ETA: 6:30 - loss: 2.5340 - accuracy: 0.72 - ETA: 6:08 - loss: 2.6020 - accuracy: 0.71 - ETA: 5:47 - loss: 2.5824 - accuracy: 0.72 - ETA: 5:25 - loss: 2.5417 - accuracy: 0.72 - ETA: 5:03 - loss: 2.5423 - accuracy: 0.72 - ETA: 4:41 - loss: 2.5341 - accuracy: 0.72 - ETA: 4:11 - loss: 2.4691 - accuracy: 0.72 - ETA: 3:49 - loss: 2.4544 - accuracy: 0.73 - ETA: 3:27 - loss: 2.4918 - accuracy: 0.72 - ETA: 3:00 - loss: 2.4325 - accuracy: 0.72 - ETA: 2:38 - loss: 2.4382 - accuracy: 0.73 - ETA: 2:16 - loss: 2.4373 - accuracy: 0.73 - ETA: 1:54 - loss: 2.4282 - accuracy: 0.73 - ETA: 1:31 - loss: 2.4554 - accuracy: 0.73 - ETA: 1:09 - loss: 2.4779 - accuracy: 0.73 - ETA: 45s - loss: 2.4263 - accuracy: 0.7306 - ETA: 22s - loss: 2.4353 - accuracy: 0.731 - 1397s 28s/step - loss: 2.4289 - accuracy: 0.7315 - val_loss: 1.1805 - val_accuracy: 0.8987
# Epoch 4/10
# 50/50 [==============================] - ETA: 21:46 - loss: 2.3809 - accuracy: 0.718 - ETA: 21:24 - loss: 1.9865 - accuracy: 0.750 - ETA: 20:54 - loss: 2.1630 - accuracy: 0.739 - ETA: 20:46 - loss: 2.0778 - accuracy: 0.710 - ETA: 16:23 - loss: 1.6623 - accuracy: 0.713 - ETA: 16:36 - loss: 1.5030 - accuracy: 0.751 - ETA: 16:40 - loss: 1.8018 - accuracy: 0.751 - ETA: 16:34 - loss: 1.8860 - accuracy: 0.760 - ETA: 16:23 - loss: 1.8591 - accuracy: 0.762 - ETA: 16:09 - loss: 2.0002 - accuracy: 0.750 - ETA: 16:00 - loss: 1.9417 - accuracy: 0.750 - ETA: 15:42 - loss: 2.0234 - accuracy: 0.745 - ETA: 14:09 - loss: 1.8678 - accuracy: 0.745 - ETA: 13:56 - loss: 1.8449 - accuracy: 0.753 - ETA: 13:40 - loss: 1.7998 - accuracy: 0.758 - ETA: 13:23 - loss: 1.8180 - accuracy: 0.766 - ETA: 13:05 - loss: 1.7847 - accuracy: 0.769 - ETA: 12:50 - loss: 1.8512 - accuracy: 0.772 - ETA: 11:48 - loss: 1.7642 - accuracy: 0.772 - ETA: 11:30 - loss: 1.7682 - accuracy: 0.777 - ETA: 11:12 - loss: 1.8195 - accuracy: 0.778 - ETA: 10:54 - loss: 1.7910 - accuracy: 0.782 - ETA: 10:34 - loss: 1.8598 - accuracy: 0.780 - ETA: 10:14 - loss: 1.8368 - accuracy: 0.783 - ETA: 9:55 - loss: 1.7908 - accuracy: 0.789 - ETA: 9:34 - loss: 1.8492 - accuracy: 0.78 - ETA: 9:12 - loss: 1.8725 - accuracy: 0.78 - ETA: 8:50 - loss: 1.9010 - accuracy: 0.78 - ETA: 8:28 - loss: 1.8949 - accuracy: 0.78 - ETA: 7:48 - loss: 1.8317 - accuracy: 0.78 - ETA: 7:26 - loss: 1.8217 - accuracy: 0.78 - ETA: 7:06 - loss: 1.8472 - accuracy: 0.78 - ETA: 6:44 - loss: 1.8765 - accuracy: 0.77 - ETA: 6:21 - loss: 1.8536 - accuracy: 0.77 - ETA: 5:47 - loss: 1.8006 - accuracy: 0.77 - ETA: 5:26 - loss: 1.8265 - accuracy: 0.77 - ETA: 5:03 - loss: 1.8640 - accuracy: 0.77 - ETA: 4:41 - loss: 1.8433 - accuracy: 0.77 - ETA: 4:19 - loss: 1.8962 - accuracy: 0.77 - ETA: 3:50 - loss: 1.8488 - accuracy: 0.77 - ETA: 3:27 - loss: 1.8460 - accuracy: 0.77 - ETA: 3:05 - loss: 1.8589 - accuracy: 0.77 - ETA: 2:42 - loss: 1.8504 - accuracy: 0.77 - ETA: 2:20 - loss: 1.8485 - accuracy: 0.77 - ETA: 1:57 - loss: 1.8307 - accuracy: 0.78 - ETA: 1:34 - loss: 1.8243 - accuracy: 0.78 - ETA: 1:10 - loss: 1.8311 - accuracy: 0.77 - ETA: 47s - loss: 1.8132 - accuracy: 0.7830 - ETA: 23s - loss: 1.8155 - accuracy: 0.784 - 1439s 29s/step - loss: 1.7942 - accuracy: 0.7864 - val_loss: 5.7160e-10 - val_accuracy: 0.9205
# Epoch 5/10
# 50/50 [==============================] - ETA: 21:41 - loss: 1.2597 - accuracy: 0.875 - ETA: 11:01 - loss: 0.6299 - accuracy: 0.878 - ETA: 14:35 - loss: 1.1865 - accuracy: 0.815 - ETA: 15:47 - loss: 1.2727 - accuracy: 0.804 - ETA: 16:20 - loss: 1.3677 - accuracy: 0.782 - ETA: 16:33 - loss: 1.2433 - accuracy: 0.801 - ETA: 16:35 - loss: 1.4669 - accuracy: 0.782 - ETA: 14:15 - loss: 1.2836 - accuracy: 0.783 - ETA: 14:22 - loss: 1.2574 - accuracy: 0.796 - ETA: 14:30 - loss: 1.3429 - accuracy: 0.802 - ETA: 14:25 - loss: 1.3958 - accuracy: 0.800 - ETA: 14:17 - loss: 1.4415 - accuracy: 0.801 - ETA: 12:53 - loss: 2.0308 - accuracy: 0.798 - ETA: 12:46 - loss: 1.9971 - accuracy: 0.802 - ETA: 12:37 - loss: 2.1380 - accuracy: 0.798 - ETA: 12:26 - loss: 2.1942 - accuracy: 0.792 - ETA: 12:16 - loss: 2.1228 - accuracy: 0.793 - ETA: 11:16 - loss: 2.0049 - accuracy: 0.794 - ETA: 11:04 - loss: 1.9457 - accuracy: 0.793 - ETA: 10:50 - loss: 1.9518 - accuracy: 0.790 - ETA: 10:35 - loss: 1.9932 - accuracy: 0.788 - ETA: 10:19 - loss: 1.9787 - accuracy: 0.786 - ETA: 10:02 - loss: 1.9103 - accuracy: 0.795 - ETA: 9:46 - loss: 1.9317 - accuracy: 0.795 - ETA: 9:28 - loss: 1.9285 - accuracy: 0.79 - ETA: 9:08 - loss: 1.9153 - accuracy: 0.79 - ETA: 8:49 - loss: 1.9194 - accuracy: 0.79 - ETA: 8:08 - loss: 1.8508 - accuracy: 0.79 - ETA: 7:49 - loss: 1.8976 - accuracy: 0.79 - ETA: 7:30 - loss: 1.8978 - accuracy: 0.79 - ETA: 7:11 - loss: 1.9268 - accuracy: 0.79 - ETA: 6:50 - loss: 1.9670 - accuracy: 0.79 - ETA: 6:29 - loss: 1.9368 - accuracy: 0.79 - ETA: 5:56 - loss: 1.8800 - accuracy: 0.79 - ETA: 5:36 - loss: 1.8804 - accuracy: 0.79 - ETA: 5:15 - loss: 1.8542 - accuracy: 0.80 - ETA: 4:54 - loss: 1.8619 - accuracy: 0.80 - ETA: 4:33 - loss: 1.8429 - accuracy: 0.80 - ETA: 4:11 - loss: 1.8732 - accuracy: 0.79 - ETA: 3:49 - loss: 1.8986 - accuracy: 0.79 - ETA: 3:27 - loss: 1.9118 - accuracy: 0.79 - ETA: 3:00 - loss: 1.8663 - accuracy: 0.79 - ETA: 2:38 - loss: 1.8391 - accuracy: 0.80 - ETA: 2:16 - loss: 1.8222 - accuracy: 0.80 - ETA: 1:54 - loss: 1.8357 - accuracy: 0.80 - ETA: 1:31 - loss: 1.8055 - accuracy: 0.80 - ETA: 1:08 - loss: 1.8161 - accuracy: 0.80 - ETA: 46s - loss: 1.8346 - accuracy: 0.8021 - ETA: 22s - loss: 1.7972 - accuracy: 0.802 - 1397s 28s/step - loss: 1.7867 - accuracy: 0.8025 - val_loss: 1.1721 - val_accuracy: 0.8924
# Epoch 6/10
# 50/50 [==============================] - ETA: 21:38 - loss: 1.5845 - accuracy: 0.781 - ETA: 21:55 - loss: 1.1922 - accuracy: 0.812 - ETA: 21:16 - loss: 1.5740 - accuracy: 0.802 - ETA: 15:46 - loss: 1.1805 - accuracy: 0.804 - ETA: 16:18 - loss: 1.3385 - accuracy: 0.790 - ETA: 16:31 - loss: 1.3430 - accuracy: 0.795 - ETA: 16:33 - loss: 1.3955 - accuracy: 0.797 - ETA: 16:27 - loss: 1.6989 - accuracy: 0.786 - ETA: 16:27 - loss: 1.6551 - accuracy: 0.793 - ETA: 16:13 - loss: 1.7401 - accuracy: 0.792 - ETA: 15:56 - loss: 1.6873 - accuracy: 0.794 - ETA: 15:38 - loss: 1.6180 - accuracy: 0.801 - ETA: 15:19 - loss: 1.7387 - accuracy: 0.802 - ETA: 13:52 - loss: 1.6145 - accuracy: 0.803 - ETA: 13:37 - loss: 1.5964 - accuracy: 0.806 - ETA: 13:25 - loss: 1.5811 - accuracy: 0.806 - ETA: 13:06 - loss: 1.5493 - accuracy: 0.807 - ETA: 12:48 - loss: 1.4984 - accuracy: 0.813 - ETA: 12:28 - loss: 1.4897 - accuracy: 0.818 - ETA: 12:07 - loss: 1.5030 - accuracy: 0.818 - ETA: 11:46 - loss: 1.5664 - accuracy: 0.816 - ETA: 11:24 - loss: 1.5364 - accuracy: 0.816 - ETA: 10:32 - loss: 1.4696 - accuracy: 0.816 - ETA: 10:15 - loss: 1.4402 - accuracy: 0.819 - ETA: 9:54 - loss: 1.4030 - accuracy: 0.824 - ETA: 9:33 - loss: 1.4035 - accuracy: 0.82 - ETA: 9:11 - loss: 1.3744 - accuracy: 0.82 - ETA: 8:49 - loss: 1.3652 - accuracy: 0.82 - ETA: 8:27 - loss: 1.3411 - accuracy: 0.83 - ETA: 7:47 - loss: 1.2964 - accuracy: 0.83 - ETA: 7:27 - loss: 1.2880 - accuracy: 0.83 - ETA: 7:05 - loss: 1.2747 - accuracy: 0.83 - ETA: 6:43 - loss: 1.2583 - accuracy: 0.83 - ETA: 6:21 - loss: 1.2921 - accuracy: 0.83 - ETA: 5:58 - loss: 1.2877 - accuracy: 0.83 - ETA: 5:35 - loss: 1.2757 - accuracy: 0.83 - ETA: 5:03 - loss: 1.2412 - accuracy: 0.83 - ETA: 4:33 - loss: 1.2085 - accuracy: 0.83 - ETA: 4:11 - loss: 1.2423 - accuracy: 0.83 - ETA: 3:49 - loss: 1.2410 - accuracy: 0.83 - ETA: 3:27 - loss: 1.2624 - accuracy: 0.83 - ETA: 3:05 - loss: 1.2588 - accuracy: 0.83 - ETA: 2:42 - loss: 1.2525 - accuracy: 0.83 - ETA: 2:20 - loss: 1.2436 - accuracy: 0.83 - ETA: 1:57 - loss: 1.2416 - accuracy: 0.83 - ETA: 1:31 - loss: 1.2147 - accuracy: 0.83 - ETA: 1:09 - loss: 1.2184 - accuracy: 0.83 - ETA: 46s - loss: 1.2261 - accuracy: 0.8309 - ETA: 23s - loss: 1.2255 - accuracy: 0.830 - 1423s 28s/step - loss: 1.2351 - accuracy: 0.8294 - val_loss: 0.0020 - val_accuracy: 0.9272
# Epoch 7/10
# 50/50 [==============================] - ETA: 23:07 - loss: 0.5273 - accuracy: 0.937 - ETA: 21:54 - loss: 0.7416 - accuracy: 0.921 - ETA: 21:13 - loss: 0.9463 - accuracy: 0.864 - ETA: 20:41 - loss: 1.3936 - accuracy: 0.843 - ETA: 20:09 - loss: 1.2929 - accuracy: 0.837 - ETA: 16:31 - loss: 1.0774 - accuracy: 0.838 - ETA: 16:34 - loss: 1.0219 - accuracy: 0.849 - ETA: 16:38 - loss: 1.0041 - accuracy: 0.848 - ETA: 16:28 - loss: 1.0451 - accuracy: 0.840 - ETA: 16:14 - loss: 1.0861 - accuracy: 0.830 - ETA: 15:57 - loss: 1.2259 - accuracy: 0.828 - ETA: 15:39 - loss: 1.3239 - accuracy: 0.821 - ETA: 14:06 - loss: 1.2221 - accuracy: 0.822 - ETA: 13:53 - loss: 1.1683 - accuracy: 0.831 - ETA: 13:43 - loss: 1.1842 - accuracy: 0.827 - ETA: 13:25 - loss: 1.1384 - accuracy: 0.833 - ETA: 13:07 - loss: 1.2187 - accuracy: 0.825 - ETA: 12:48 - loss: 1.2305 - accuracy: 0.830 - ETA: 12:28 - loss: 1.1964 - accuracy: 0.829 - ETA: 12:08 - loss: 1.2046 - accuracy: 0.832 - ETA: 11:11 - loss: 1.1472 - accuracy: 0.832 - ETA: 10:55 - loss: 1.1076 - accuracy: 0.838 - ETA: 10:35 - loss: 1.1714 - accuracy: 0.836 - ETA: 10:15 - loss: 1.1400 - accuracy: 0.837 - ETA: 9:28 - loss: 1.0944 - accuracy: 0.837 - ETA: 9:09 - loss: 1.1608 - accuracy: 0.83 - ETA: 8:49 - loss: 1.1197 - accuracy: 0.83 - ETA: 8:29 - loss: 1.1556 - accuracy: 0.84 - ETA: 8:09 - loss: 1.1690 - accuracy: 0.84 - ETA: 7:48 - loss: 1.2203 - accuracy: 0.83 - ETA: 7:27 - loss: 1.2219 - accuracy: 0.83 - ETA: 7:05 - loss: 1.2620 - accuracy: 0.83 - ETA: 6:43 - loss: 1.2701 - accuracy: 0.83 - ETA: 6:21 - loss: 1.2569 - accuracy: 0.83 - ETA: 5:47 - loss: 1.3260 - accuracy: 0.83 - ETA: 5:26 - loss: 1.3203 - accuracy: 0.83 - ETA: 5:04 - loss: 1.3325 - accuracy: 0.83 - ETA: 4:41 - loss: 1.3512 - accuracy: 0.83 - ETA: 4:19 - loss: 1.3404 - accuracy: 0.83 - ETA: 3:56 - loss: 1.3113 - accuracy: 0.84 - ETA: 3:33 - loss: 1.3447 - accuracy: 0.84 - ETA: 3:10 - loss: 1.3429 - accuracy: 0.84 - ETA: 2:42 - loss: 1.3117 - accuracy: 0.84 - ETA: 2:20 - loss: 1.2974 - accuracy: 0.84 - ETA: 1:57 - loss: 1.2931 - accuracy: 0.84 - ETA: 1:33 - loss: 1.3056 - accuracy: 0.84 - ETA: 1:10 - loss: 1.3104 - accuracy: 0.84 - ETA: 46s - loss: 1.2831 - accuracy: 0.8446 - ETA: 23s - loss: 1.2801 - accuracy: 0.843 - 1425s 28s/step - loss: 1.3080 - accuracy: 0.8416 - val_loss: 1.4313e-04 - val_accuracy: 0.9146
# Epoch 8/10
# 50/50 [==============================] - ETA: 21:37 - loss: 0.6312 - accuracy: 0.812 - ETA: 10:57 - loss: 0.3156 - accuracy: 0.818 - ETA: 14:05 - loss: 0.7827 - accuracy: 0.800 - ETA: 15:27 - loss: 1.0278 - accuracy: 0.793 - ETA: 16:06 - loss: 1.1512 - accuracy: 0.829 - ETA: 16:21 - loss: 1.3636 - accuracy: 0.832 - ETA: 16:36 - loss: 1.2917 - accuracy: 0.839 - ETA: 16:30 - loss: 1.1642 - accuracy: 0.853 - ETA: 16:20 - loss: 1.0869 - accuracy: 0.856 - ETA: 16:08 - loss: 1.0984 - accuracy: 0.851 - ETA: 14:21 - loss: 0.9985 - accuracy: 0.851 - ETA: 14:13 - loss: 1.0645 - accuracy: 0.847 - ETA: 14:02 - loss: 1.0347 - accuracy: 0.853 - ETA: 13:53 - loss: 1.0460 - accuracy: 0.849 - ETA: 13:39 - loss: 1.0358 - accuracy: 0.849 - ETA: 13:22 - loss: 1.0020 - accuracy: 0.857 - ETA: 13:04 - loss: 1.0966 - accuracy: 0.852 - ETA: 12:45 - loss: 1.1219 - accuracy: 0.840 - ETA: 12:25 - loss: 1.1022 - accuracy: 0.840 - ETA: 11:26 - loss: 1.0471 - accuracy: 0.841 - ETA: 11:11 - loss: 1.0804 - accuracy: 0.839 - ETA: 10:52 - loss: 1.0509 - accuracy: 0.844 - ETA: 10:33 - loss: 1.0913 - accuracy: 0.846 - ETA: 10:13 - loss: 1.1099 - accuracy: 0.844 - ETA: 9:53 - loss: 1.0731 - accuracy: 0.847 - ETA: 9:31 - loss: 1.0897 - accuracy: 0.84 - ETA: 8:48 - loss: 1.0494 - accuracy: 0.85 - ETA: 8:29 - loss: 1.0672 - accuracy: 0.84 - ETA: 8:09 - loss: 1.0585 - accuracy: 0.85 - ETA: 7:47 - loss: 1.0551 - accuracy: 0.85 - ETA: 7:26 - loss: 1.0520 - accuracy: 0.85 - ETA: 7:04 - loss: 1.0652 - accuracy: 0.85 - ETA: 6:42 - loss: 1.0573 - accuracy: 0.85 - ETA: 6:20 - loss: 1.0664 - accuracy: 0.85 - ETA: 5:46 - loss: 1.2607 - accuracy: 0.85 - ETA: 5:25 - loss: 1.3102 - accuracy: 0.85 - ETA: 5:03 - loss: 1.3098 - accuracy: 0.85 - ETA: 4:33 - loss: 1.2753 - accuracy: 0.85 - ETA: 4:11 - loss: 1.2979 - accuracy: 0.84 - ETA: 3:49 - loss: 1.3218 - accuracy: 0.84 - ETA: 3:27 - loss: 1.3053 - accuracy: 0.84 - ETA: 3:05 - loss: 1.2908 - accuracy: 0.84 - ETA: 2:42 - loss: 1.2792 - accuracy: 0.84 - ETA: 2:16 - loss: 1.2501 - accuracy: 0.84 - ETA: 1:54 - loss: 1.2716 - accuracy: 0.84 - ETA: 1:31 - loss: 1.2876 - accuracy: 0.84 - ETA: 1:08 - loss: 1.2769 - accuracy: 0.84 - ETA: 46s - loss: 1.2718 - accuracy: 0.8469 - ETA: 23s - loss: 1.2870 - accuracy: 0.846 - 1412s 28s/step - loss: 1.2764 - accuracy: 0.8460 - val_loss: 0.0038 - val_accuracy: 0.9404
# Epoch 9/10
# 50/50 [==============================] - ETA: 21:46 - loss: 1.3892 - accuracy: 0.843 - ETA: 21:15 - loss: 1.5057 - accuracy: 0.843 - ETA: 14:06 - loss: 1.0038 - accuracy: 0.846 - ETA: 15:25 - loss: 0.9446 - accuracy: 0.855 - ETA: 16:02 - loss: 1.1582 - accuracy: 0.845 - ETA: 16:33 - loss: 1.1608 - accuracy: 0.838 - ETA: 16:36 - loss: 1.2986 - accuracy: 0.844 - ETA: 16:30 - loss: 1.2820 - accuracy: 0.844 - ETA: 16:20 - loss: 1.4159 - accuracy: 0.840 - ETA: 16:06 - loss: 1.3345 - accuracy: 0.844 - ETA: 14:20 - loss: 1.2132 - accuracy: 0.844 - ETA: 14:12 - loss: 1.3056 - accuracy: 0.838 - ETA: 14:07 - loss: 1.2532 - accuracy: 0.844 - ETA: 13:53 - loss: 1.2236 - accuracy: 0.842 - ETA: 13:38 - loss: 1.2163 - accuracy: 0.837 - ETA: 13:22 - loss: 1.1718 - accuracy: 0.844 - ETA: 13:04 - loss: 1.1576 - accuracy: 0.844 - ETA: 12:45 - loss: 1.1446 - accuracy: 0.842 - ETA: 12:25 - loss: 1.1907 - accuracy: 0.838 - ETA: 11:27 - loss: 1.1312 - accuracy: 0.839 - ETA: 11:11 - loss: 1.1055 - accuracy: 0.842 - ETA: 10:53 - loss: 1.0781 - accuracy: 0.842 - ETA: 10:33 - loss: 1.0591 - accuracy: 0.842 - ETA: 9:45 - loss: 1.0150 - accuracy: 0.843 - ETA: 9:27 - loss: 0.9987 - accuracy: 0.84 - ETA: 9:08 - loss: 1.0086 - accuracy: 0.84 - ETA: 8:50 - loss: 1.0063 - accuracy: 0.84 - ETA: 8:29 - loss: 1.0214 - accuracy: 0.84 - ETA: 8:08 - loss: 1.0415 - accuracy: 0.84 - ETA: 7:47 - loss: 1.1029 - accuracy: 0.84 - ETA: 7:26 - loss: 1.1357 - accuracy: 0.84 - ETA: 7:04 - loss: 1.1325 - accuracy: 0.84 - ETA: 6:42 - loss: 1.1258 - accuracy: 0.84 - ETA: 6:08 - loss: 1.0926 - accuracy: 0.84 - ETA: 5:47 - loss: 1.0863 - accuracy: 0.85 - ETA: 5:25 - loss: 1.0562 - accuracy: 0.85 - ETA: 4:54 - loss: 1.0276 - accuracy: 0.85 - ETA: 4:33 - loss: 1.0239 - accuracy: 0.85 - ETA: 4:11 - loss: 1.0596 - accuracy: 0.85 - ETA: 3:49 - loss: 1.0603 - accuracy: 0.85 - ETA: 3:27 - loss: 1.0774 - accuracy: 0.84 - ETA: 3:05 - loss: 1.0521 - accuracy: 0.85 - ETA: 2:38 - loss: 1.0276 - accuracy: 0.85 - ETA: 2:16 - loss: 1.0419 - accuracy: 0.85 - ETA: 1:54 - loss: 1.0392 - accuracy: 0.85 - ETA: 1:31 - loss: 1.0245 - accuracy: 0.85 - ETA: 1:08 - loss: 1.0086 - accuracy: 0.86 - ETA: 46s - loss: 1.0071 - accuracy: 0.8605 - ETA: 22s - loss: 1.1031 - accuracy: 0.859 - 1398s 28s/step - loss: 1.1180 - accuracy: 0.8595 - val_loss: 0.6638 - val_accuracy: 0.9019
# Epoch 10/10
# 50/50 [==============================] - ETA: 21:36 - loss: 0.5477 - accuracy: 0.937 - ETA: 21:14 - loss: 0.8206 - accuracy: 0.906 - ETA: 20:46 - loss: 0.9494 - accuracy: 0.885 - ETA: 20:19 - loss: 0.8465 - accuracy: 0.890 - ETA: 20:10 - loss: 0.6919 - accuracy: 0.906 - ETA: 19:42 - loss: 0.5966 - accuracy: 0.911 - ETA: 19:14 - loss: 0.6168 - accuracy: 0.901 - ETA: 18:46 - loss: 0.9937 - accuracy: 0.886 - ETA: 16:21 - loss: 1.2083 - accuracy: 0.883 - ETA: 16:07 - loss: 1.2771 - accuracy: 0.878 - ETA: 15:51 - loss: 1.2093 - accuracy: 0.875 - ETA: 15:39 - loss: 1.1425 - accuracy: 0.881 - ETA: 15:20 - loss: 1.0792 - accuracy: 0.883 - ETA: 14:59 - loss: 1.0761 - accuracy: 0.884 - ETA: 14:37 - loss: 1.0567 - accuracy: 0.884 - ETA: 14:15 - loss: 0.9984 - accuracy: 0.885 - ETA: 13:53 - loss: 0.9666 - accuracy: 0.890 - ETA: 13:30 - loss: 1.0567 - accuracy: 0.882 - ETA: 12:25 - loss: 1.0011 - accuracy: 0.882 - ETA: 12:08 - loss: 1.0009 - accuracy: 0.880 - ETA: 11:47 - loss: 1.0079 - accuracy: 0.875 - ETA: 11:25 - loss: 0.9626 - accuracy: 0.881 - ETA: 11:03 - loss: 1.0768 - accuracy: 0.872 - ETA: 10:41 - loss: 1.0888 - accuracy: 0.871 - ETA: 10:18 - loss: 1.0658 - accuracy: 0.869 - ETA: 9:31 - loss: 1.0248 - accuracy: 0.870 - ETA: 9:11 - loss: 1.0413 - accuracy: 0.86 - ETA: 8:49 - loss: 1.0962 - accuracy: 0.86 - ETA: 8:09 - loss: 1.0584 - accuracy: 0.86 - ETA: 7:47 - loss: 1.0530 - accuracy: 0.86 - ETA: 7:26 - loss: 1.0518 - accuracy: 0.86 - ETA: 7:04 - loss: 1.0434 - accuracy: 0.86 - ETA: 6:43 - loss: 1.1028 - accuracy: 0.85 - ETA: 6:21 - loss: 1.0957 - accuracy: 0.85 - ETA: 5:47 - loss: 1.0644 - accuracy: 0.85 - ETA: 5:25 - loss: 1.0351 - accuracy: 0.86 - ETA: 5:03 - loss: 1.0422 - accuracy: 0.86 - ETA: 4:41 - loss: 1.0710 - accuracy: 0.86 - ETA: 4:18 - loss: 1.0560 - accuracy: 0.86 - ETA: 3:56 - loss: 1.0850 - accuracy: 0.85 - ETA: 3:33 - loss: 1.0947 - accuracy: 0.85 - ETA: 3:10 - loss: 1.1023 - accuracy: 0.85 - ETA: 2:42 - loss: 1.0767 - accuracy: 0.85 - ETA: 2:19 - loss: 1.0877 - accuracy: 0.86 - ETA: 1:57 - loss: 1.0792 - accuracy: 0.85 - ETA: 1:33 - loss: 1.0608 - accuracy: 0.86 - ETA: 1:10 - loss: 1.0797 - accuracy: 0.86 - ETA: 46s - loss: 1.0572 - accuracy: 0.8605 - ETA: 23s - loss: 1.0563 - accuracy: 0.860 - 1425s 28s/step - loss: 1.0689 - accuracy: 0.8597 - val_loss: 0.0233 - val_accuracy: 0.8987

# %%
#import pickle

#filename = 'finalized_model.sav'
#pickle.dump(model, open(filename, 'wb'))


#filename = 'finalized_his.sav'
#pickle.dump(history, open(filename, 'wb'))


####save model and load later

# serialize model to JSON
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model.h5")
print("Saved model to disk")


#### later we can load this model form disk
# json_file = open('model.json', 'r')
# loaded_model_json = json_file.read()
# json_file.close()
# loaded_model = model_from_json(loaded_model_json)
#
# Out:
# Saved model to disk

# %%
json_file = open('2019-06-07_VGG_model.h5', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-29-b155a35dc4bf> in <module>
#       1 json_file = open('2019-06-07_VGG_model.h5', 'r')
# ----> 2 loaded_model_json = json_file.read()
#       3 json_file.close()
#       4 loaded_model = model_from_json(loaded_model_json)
#
# ~\Anaconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x90 in position 14096: character maps to <undefined>

# %% [markdown]
# ## <a id='perf'>4.3. Model Performance</a>

# %%
# plot model performance
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(1, len(history.epoch) + 1)

plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Set')
plt.plot(epochs_range, val_acc, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Set')
plt.plot(epochs_range, val_loss, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss')

plt.tight_layout()
plt.show()

# %%
# validate on val set
predictions = model.predict(X_val_prep)
predictions = [1 if x>0.5 else 0 for x in predictions]

accuracy = accuracy_score(y_val, predictions)
print('Val Accuracy = %.2f' % accuracy)

confusion_mtx = confusion_matrix(y_val, predictions) 
cm = plot_confusion_matrix(confusion_mtx, classes = list(labels.items()), normalize=False)
# Out:
# Val Accuracy = 0.92

# %%
# validate on test set
predictions = model.predict(X_test_prep)
predictions = [1 if x>0.5 else 0 for x in predictions]

accuracy = accuracy_score(y_test, predictions)
print('Test Accuracy = %.2f' % accuracy)

confusion_mtx = confusion_matrix(y_test, predictions) 
cm = plot_confusion_matrix(confusion_mtx, classes = list(labels.items()), normalize=False)
# Out:
# Test Accuracy = 1.00

# %% [markdown]
# Now let's take a look at the images from the `test set` that were misclassified:

# %%
ind_list = np.argwhere((y_test == predictions) == False)[:, -1]
if ind_list.size == 0:
    print('There are no missclassified images.')
else:
    for i in ind_list:
        plt.figure()
        plt.imshow(X_test_crop[i])
        plt.xticks([])
        plt.yticks([])
        plt.title(f'Actual class: {y_val[i]}\nPredicted class: {predictions[i]}')
        plt.show()
# Out:
# There are no missclassified images.

# %% [markdown]
# First scan looks a bit misleading - what is that light spot in the middle? 🤔 I can clearly see why model classified it as `Tumor`.

# %% [markdown]
# # <a id='concl'>5. Conclusions</a>
#
# This project was a combination of CNN model classification problem (to predict wheter the subject has brain tumor or not) & Computer Vision problem (to automate the process of brain cropping from MRI scans). The final accuracy is much higher than 50% baseline (random guess). However, it could be increased by larger number of train images or through model hyperparameters tuning.

# %%
# clean up the space
# !rm -rf TRAIN TEST VAL TRAIN_CROP TEST_CROP VAL_CROP
# save the model
model.save('2019-06-07_VGG_model.h5')
# Out:
# 'rm' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from sklearn.metrics import roc_curve, auc

fpr, tpr, _ = roc_curve(y_test, predictions)


roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
